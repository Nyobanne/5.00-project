# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# # 01 - Problem (Case Study)
# * Data Description.
# * Goal.

# %%
#Data: excel files
#https://doc.agribalyse.fr/documentation/utiliser-agribalyse/acces-donnees
#conv : agricultural impacts of conventional farming. rows are standardized ingredients, at farm door.
    #we only have agri impact (not transfo etc.)
#ciqual: nutritional values of ingredients
#tbc: link it with eurostat prices? vs organic?

# %% [markdown]
# Linking nutritional « quality » to environmental impact
# * Is there any correlation between macro/micronutrient richness and environmental impact?
# * if not, which food categories are the most impactful?
# * Which nutritional indicator is the most impactful?
# Data source:
# *Agribalyse (France) environmental impacts of agricultural and food products throughout their life cycles

# %%
#/kg ingredient

# %% [markdown]
# # 02 - Getting the data

# %%
#conv : agricultural impacts of conventional farming. rows are standardized ingredients, at farm door
#ciqual: nutritional values of ingredients

# %%
sheet_indexes_to_read = [0, 1, 2]
dfs = pd.read_excel('AGRIBALYSE3.1.1_partie agriculture_conv_janv24.xlsx',skiprows=1,sheet_name=sheet_indexes_to_read)
 # sheet 0 is not interesting
df_sheet2 = dfs[1]  # Sheet 1 is environmental impact
df_sheet3 = dfs[2] #Sheet 2 is toxicology

for sheet_name, df in dfs.items():
    print(f"Sheet: {sheet_name}")
    display(df.head())  # Display the first few rows
# Out:
# Sheet: 0
#            Version : Agribalyse v3.1.1; Juillet 2023
# 0  Date dernière modification du fichier : 31/01/...
# 1                                                NaN
# 2  Onglet AGB_agri_conv_3.1.1 : facteurs d'impact...
# 3  Onglet AGB_agri_conv_3.1.1_detailsTox : facteu...
# 4                                                NaN
# Sheet: 1
#                                           Unnamed: 0  \
# 0                         Nom du Produit en Français
# 1  Agneau système de production conventionnel en ...
# 2  Agneau, conventionnel, système Roquefort, à la...
# 3  Algue production non optimisée, 1 kg d'algues ...
# 4  Algue production optimisée, 1 kg d'algues (Lam...
#
#                                           Unnamed: 1  \
# 0                                           LCI Name
# 1  Lamb, conventional, indoor production system, ...
# 2  Lamb, conventional, Roquefort system, at farm ...
# 3  Seaweed non-optimized production, 1kg algae (L...
# ...

# %% [markdown]
# # 03(a) - Cleaning/Wrangling
# * Change headers names.
# * Deal with NaN values.

# %%
#naming columns
#column 1 is in French : can be removed for analysis
#removing "at the gate"

# %%
print(df_sheet2.columns)
# Out:
# Index(['Product name in French_Unnamed: 0_Product name in French',
#        'LCI Name_Unnamed: 1_LCI Name', 'Category_Unnamed: 2_Category',
#        'mPt/kg_Score unique EF3.1_mPt/kg',
#        'kg CO2 eq/kg_Climate change_kg CO2 eq/kg',
#        'kg CFC11 eq/kg_Ozone's impoverishment_kg CFC11 eq/kg',
#        'kBq U-235 eq/kg_Ionizing radiation_kBq U-235 eq/kg',
#        'kg NMVOC eq/kg_Ozone photochemical training_kg NMVOC eq/kg',
#        'disease inc./kg_Particles_disease inc./kg',
#        'CTUh/kg_Toxicological effects on human health: non-cancer substances*_CTUh/kg',
#        'CTUh/kg_Toxicological effects on human health: carcinogenic substances*_CTUh/kg',
#        'mol H+ eq/kg_Terrestrial acidification and fresh waters_mol H+ eq/kg',
#        'kg P eq/kg_EUTROPHICATION SOURCE WATERS_kg P eq/kg',
#        'kg N eq/kg_Marine eutrophication_kg N eq/kg',
#        'mol N eq/kg_Earthly eutrophication_mol N eq/kg',
# ...

# %% [markdown]
# # 03(b) - EDA
# * Categorical Features.
# * Numerical Features.
# *  Exploration.

# %% [markdown]
# # 04 - Processing Data
# * Dealing with outliers.
# * Normalization.
# * Encoding Categorical Data.
# * Splitting into train set and test set.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 05 - Modeling

# %% [markdown]
# # 06 - Model Validation
# * R2.
# * MSE.
# * RMSE.
# * MAE.

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # 07 - Reporting
# * Present results.

# %% [markdown]
# # 08 - Validation Data
