# %% [markdown]
# # 01 - Data description

# %% [markdown]
# #### Data sources:
# - Ciqual : nutritional values (/100g) of ingredients https://ciqual.anses.fr/#/cms/download/node/20
#
# - Agribalyse: environmental impacts (/kg) of food throughout the life cycle  https://doc.agribalyse.fr/documentation/utiliser-agribalyse/acces-donnees
# ####  Scope
# -  Franc ,  conventional farmin, 3000 food itemsg
# * Is there any correlation between nutrient richness and environmental impact?
# * if not, which food categories are the most impactful?
# * Which nutritional indicator is the most impactful??

# %% [markdown]
# #### (Env) indicators
# * calculation of EF_score
# * source: https://eplca.jrc.ec.europa.eu/permalink/PEF_method.pdf
#
# | Column   Name       | Detail                                     | Contribution in EF_Score |
# |---------------------|--------------------------------------------|--------------------------|
# | Carbon              | Climate change                             | 21.5                     |
# | Ozone_CFC           | Ozone depletion                            | 3.0                      |
# | Tox_human_carc      | Human toxicity, cancer                     | 6.0                      |
# | Tox_human           | Human toxicity, non-cancer                 | 0.1                      |
# | Particulates        | Particulate matter                         | 14.9                     |
# | Ionising            | Ionizing radiation, human health           | 0.5                      |
# | NMVOC               | Photochemical ozone formation, human health| 2.4                      |
# | Sweet_water_Acid    | Acidification                              | 1.5                      |
# | Earth_Eutroph       | Eutrophication, terrestrial                | 1.0                      |
# | Sweet_Water_Eutroph | Eutrophication, freshwater                 | 1.0                      |
# | Marine_Eutroph      | Eutrophication, marine                     | 0.1                      |
# | Water_Ecotox        | Ecotoxicity, freshwater                    | 0.1                      |
# | LU                  | Land use                                   | 14.3                     |
# | WU                  | Water use                                  | 18.6                     |
# | MU                  | Resource use, minerals and metals          | 6.7                      |
# | Energy              | Resource use, fossils                      | 8.3                      |
#
# Stages:
#
# | Stage Name | Stage Description   |
# |------------|---------------------|
# | Farm       | at farm gate        |
# | Process    | transformation      |
# | Pack       | packaging           |
# | Transp     | transportation      |
# | Distrib    | Distribution        |
# | Consum     | Consumer            |
# | Total      | Sum of the above    |

# %% [markdown]
# #### (Nut) indicators
# | Name                                     | Units     |   | Name                                     | Units     |
# |------------------------------------------|-----------|---|------------------------------------------|-----------|
# | Energy, Regulation EU No 1169/2011      | kJ/100g   |   | Energy, Regulation EU No 1169/2011      | kcal/100g |
# | Energy, N x Jones' factor, with fibres  | kJ/100g   |   | Energy, N x Jones' factor, with fibres  | kcal/100g |
# | Water                                    | g/100g    |   | Protein                                  | g/100g    |
# | Carbohydrate                             | g/100g    |   | Fat                                      | g/100g    |
# | Sugars                                   | g/100g    |   | Fibres                                   | g/100g    |
# | Ash                                      | g/100g    |   | Alcohol                                  | g/100g    |
# | FA saturated                             | g/100g    |   | FA mono                                  | g/100g    |
# | FA poly                                  | g/100g    |   | Salt                                     | g/100g    |
# | Calcium                                  | mg/100g   |   | Iron                                     | mg/100g   |
# | Magnesium                                | mg/100g   |   | Phosphorus                               | mg/100g   |
# | Potassium                                | mg/100g   |   | Sodium                                   | mg/100g   |
# | Zinc                                     | mg/100g   |   | Vitamin C                                | mg/100g   |
# | Vitamin B1 or Thiamin                    | mg/100g   |   | Vitamin B2 or Riboflavin                | mg/100g   |
# | Vitamin B3 or Niacin                    | mg/100g   |   | Vitamin B6                               | mg/100g   |
# | Vitamin B9 or Folate                     | µg/100g   |   |                                           |           |

# %% [markdown]
# #### Food Groups
# | GroupName                                | GroupCode |
# |------------------------------------------|-----------|
# | baby food                                | 11        |
# | beverages                                | 06        |
# | cereal products                          | 03        |
# | fats and oils                           | 09        |
# | fruits, vegetables, legumes and nuts    | 02        |
# | ice cream and sorbet                     | 08        |
# | meat, egg and fish                       | 04        |
# | milk and milk products                   | 05        |
# | miscellaneous                            | 10        |
# | starters and dishes                      | 01        |
# | sugar and confectionery                  | 07        |

# %% [markdown]
# #### Food SubGroups
# | SubgroupName                               | SubgroupeCode |   | SubgroupName                               | SubgroupeCode |
# |--------------------------------------------|---------------|---|--------------------------------------------|---------------|
# | alcoholic beverages                        | 0603          |   | other meat products                        | 0404          |
# | baby biscuits and cereals                  | 1104          |   | pasta, rice and grains                     | 0301          |
# | baby deserts                               | 1103          |   | pizzas, crepe and pies                     | 0104          |
# | baby dishes                                | 1102          |   | potatoes and other tubers                  | 0202          |
# | baby milk and beverages                    | 1101          |   | raw meat                                   | 0402          |
# | breads and similar                         | 0302          |   | salts                                      | 1004          |
# | breakfast cereals                          | 0707          |   | sandwiches                                 | 0105          |
# | butters                                    | 0901          |   | sauces                                     | 1001          |
# | cakes and pastry                           | 0709          |   | savoury biscuits                           | 0303          |
# | cereal bars                                | 0708          |   | savoury pastries and other starters        | 0106          |
# | cheese and similar                         | 0503          |   | seafood, cooked                            | 0407          |
# | chocolate and chocolate products           | 0702          |   | seafood, raw                               | 0408          |
# | condiments                                 | 1002          |   | seaweed                                    | 1007          |
# | cooked meat                                | 0401          |   | sorbet                                     | 0802          |
# | cooking aids                               | 1003          |   | soups                                      | 0102          |
# | cream and similar                          | 0504          |   | spices                                     | 1005          |
# | dairy products and similar                 | 0502          |   | sugars and honey                           | 0701          |
# | delicatessen meat and similar              | 0403          |   | sweet biscuits                             | 0706          |
# | dishes                                     | 0103          |   | vegetable oils                             | 0902          |
# | eggs                                       | 0410          |   | vegetables                                 | 0201          |
# | fish oils                                  | 0904          |   | Viennese pastries                          | 0705          |
# | fish products                              | 0409          |   | water                                      | 0601          |
# | fish, cooked                               | 0405          |   |                                             |               |
# | fish, raw                                  | 0406          |   |                                             |               |
# | foods for particular nutritional uses     | 1008          |   |                                             |               |
# | frozen desserts                            | 0803          |   |                                             |               |
# | fruits                                     | 0204          |   |                                             |               |
# | herbs                                      | 1006          |   |                                             |               |
# | ice cream                                  | 0801          |   |                                             |               |
# | jam                                        | 0704          |   |                                             |               |
# | legumes                                    | 0203          |   |                                             |               |
# | margarines                                 | 0903          |   |                                             |               |
# | meat substitute                            | 0411          |   |                                             |               |
# | milk                                       | 0501          |   |                                             |               |
# | miscellaneous ingredients                  | 1009          |   |                                             |               |
# | miscellaneous ingredients for vegetarian   | 1009          |   |                                             |               |
# | mixed salads                               | 0101          |   |                                             |               |
# | non-alcoholic beverages                    | 0602          |   |                                             |               |
# | non-chocolate confectionery                | 0703          |   |                                             |               |
# | nuts and seeds                             | 0205          |   |                                             |               |
# | other fats                                 | 0905          |   |                                             |               |

# %% [markdown]
# # 02 - Getting the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
#Source table is an excel file with sheet Ciqual (nut) and sheet Agribalyse (env)
#rows are standardized ingredients

# %%
#pip install xlrd

# %%
data_env = pd.read_excel('Ciqual_Agribalyse.xls',skiprows=2,sheet_name='env steps')# environmental impact
data_nut = pd.read_excel('Ciqual_Agribalyse.xls',sheet_name='nut') #nutritionals
# Display the first few rows

display(data_nut.head())  
display(data_env.head())
# Out:
#    alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code     alim_grp_nom_eng  \
# 0              0                0                  0                  NaN
# 1              1              101                  0  starters and dishes
# 2              1              101                  0  starters and dishes
# 3              1              101                  0  starters and dishes
# 4              1              101                  0  starters and dishes
#
#   alim_ssgrp_nom_eng alim_ssssgrp_nom_eng  ciqual_code  \
# 0                NaN                  NaN        24999
# 1       mixed salads                    -        25601
# 2       mixed salads                    -        25602
# 3       mixed salads                    -        25605
# 4       mixed salads                    -        25606
#
#                                       alim_nom_eng alim_nom_sci  \
# 0                                 Desert (average)          NaN
# ...

# %% [markdown]
# # 03 - Cleaning/Wrangling

# %%
#need to merge both into 1 df
df = pd.merge(data_env, data_nut, left_on='CIQUAL_code', right_on='ciqual_code', how='inner')

display(df.head())
# Out:
#   Code AGB  CIQUAL_code                                   Group Subgroup  \
# 0    11084        11084  aides culinaires et ingrédients divers   algues
# 1    11023        11023  aides culinaires et ingrédients divers   herbes
# 2    11000        11000  aides culinaires et ingrédients divers   herbes
# 3    11093        11093  aides culinaires et ingrédients divers   herbes
# 4    20995        20995  aides culinaires et ingrédients divers   algues
#
#                           Nom du Produit en Français  \
# 0                                  Agar (algue), cru
# 1                                  Ail séché, poudre
# 2                                           Ail, cru
# 3                                       Aneth, frais
# 4  Ao-nori (Enteromorpha sp.), séchée ou déshydratée
#
#                                             LCI Name   DQR  \
# 0                                 Seaweed, agar, raw  2.99
# 1                              Garlic, powder, dried  4.11
# ...

# %%
#Replace column names
#alim_ssssgrp_nom_eng with SubSubgroup_name from data_env
#alim_ssgrp_nom_eng with Subgroup_name
#alim_grp_nom_eng with Group_name
#alim_grp_code with Group_code
#alim_nom_eng with Food_name
#alim_ssgrp_code with Subgroup_code
column_newnames = {
    'alim_ssssgrp_nom_eng': 'SubSubgroup_name',
    'alim_ssssgrp_code':'SubSubgroup_code',
    'alim_ssgrp_nom_eng': 'Subgroup_name',
    'alim_grp_nom_eng': 'Group_name',
    'alim_grp_code': 'Group_code',
    'alim_nom_eng': 'Food_name',
    'alim_ssgrp_code': 'Subgroup_code',
    'EU Farm':'Energy Farm'
}

# Rename the columns using the rename() method
df.rename(columns=column_newnames, inplace=True)

# %%
for column in df.columns:
    print(f": {column}, dtype: {df[column].dtype}")
# Out:
# : Code AGB, dtype: object
# : CIQUAL_code, dtype: int64
# : Group, dtype: object
# : Subgroup, dtype: object
# : Nom du Produit en Français, dtype: object
# : LCI Name, dtype: object
# : DQR, dtype: float64
# : Nom et code, dtype: object
# : EF_Score Farm, dtype: float64
# : EF_Score Process, dtype: float64
# : EF_Score Pack, dtype: float64
# : EF_Score Transp, dtype: float64
# : EF_Score Distrib, dtype: float64
# : EF_Score Consum, dtype: float64
# : EF_Score Total, dtype: float64
# : Carbon Farm, dtype: float64
# : Carbon Process, dtype: float64
# : Carbon Pack, dtype: float64
# : Carbon Transp, dtype: float64
# : Carbon Distrib, dtype: float64
# : Carbon Consum, dtype: float64
# : Carbon Total, dtype: float64
# : Ozone_CFC Farm, dtype: float64
# : Ozone_CFC Process, dtype: float64
# : Ozone_CFC Pack, dtype: float64
# : Ozone_CFC Transp, dtype: float64
# : Ozone_CFC Distrib, dtype: float64
# : Ozone_CFC Consum, dtype: float64
# : Ozone_CFC Total, dtype: float64
# ...

# %%
#we will assume that columns Group and Subgroup, which are not translated, are already covered by data_nut columns
group_count = df['Group'].value_counts()
print(group_count.to_string())
#subgroups are more detailed; but not that important for the analysis 
#subgroup_count = df['Subgroup'].value_counts()
# Out:
# Group
# viandes, œufs, poissons                        642
# fruits, légumes, légumineuses et oléagineux    423
# produits céréaliers                            375
# entrées et plats composés                      292
# boissons                                       227
# lait et produits laitiers                      223
# aides culinaires et ingrédients divers         161
# matières grasses                                56
# produits sucrés                                 53
# aliments infantiles                             33
# glaces et sorbets                               25

# %%
# drop certain columns:
#Group, Subgroup, Nom du Produit en Français, Nom et code, Unnamed, alim_nom_sci, ciqual_code
columns_to_drop = ['Group', 'Subgroup', 'Nom du Produit en Français', 'Nom et code', 'alim_nom_sci','ciqual_code']
df.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ## Nutritionals

# %%
columns_to_convert = [
    'Group_code', 'Subgroup_code', 'SubSubgroup_code',
    'Energy, Regulation EU No 1169/2011 (kJ/100g)',
    'Energy, Regulation EU No 1169/2011 (kcal/100g)',
    'Energy, N x Jones\' factor, with fibres (kJ/100g)',
    'Energy, N x Jones\' factor, with fibres (kcal/100g)',
    'Water (g/100g)', 'Protein (g/100g)', 'Protein, crude, N x 6.25 (g/100g)',
    'Carbohydrate (g/100g)', 'Fat (g/100g)', 'Sugars (g/100g)',
    'fructose (g/100g)', 'galactose (g/100g)', 'glucose (g/100g)',
    'lactose (g/100g)', 'maltose (g/100g)', 'sucrose (g/100g)',
    'Starch (g/100g)', 'Fibres (g/100g)', 'Polyols (g/100g)', 'Ash (g/100g)',
    'Alcohol (g/100g)', 'Organic acids (g/100g)', 'FA saturated (g/100g)',
    'FA mono (g/100g)', 'FA poly (g/100g)', 'FA 4:0 (g/100g)', 'FA 6:0 (g/100g)',
    'FA 8:0 (g/100g)', 'FA 10:0 (g/100g)', 'FA 12:0 (g/100g)', 'FA 14:0 (g/100g)',
    'FA 16:0 (g/100g)', 'FA 18:0 (g/100g)', 'FA 18:1 n-9 cis (g/100g)',
    'FA 18:2 9c,12c (n-6) (g/100g)', 'FA 18:3 c9,c12,c15 (n-3) (g/100g)',
    'FA 20:4 5c,8c,11c,14c (n-6) (g/100g)', 'FA 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100g)',
    'FA 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100g)', 'Cholesterol (mg/100g)',
    'Salt (g/100g)', 'Calcium (mg/100g)', 'Chloride (mg/100g)', 'Copper (mg/100g)',
    'Iron (mg/100g)', 'Iodine (µg/100g)', 'Magnesium (mg/100g)', 'Manganese (mg/100g)',
    'Phosphorus (mg/100g)', 'Potassium (mg/100g)', 'Selenium (µg/100g)', 'Sodium (mg/100g)',
    'Zinc (mg/100g)', 'Retinol (µg/100g)', 'Beta-carotene (µg/100g)', 'Vitamin D (µg/100g)',
    'Vitamin E (mg/100g)', 'Vitamin K1 (µg/100g)', 'Vitamin K2 (µg/100g)', 'Vitamin C (mg/100g)',
    'Vitamin B1 or Thiamin (mg/100g)', 'Vitamin B2 or Riboflavin (mg/100g)',
    'Vitamin B3 or Niacin (mg/100g)', 'Vitamin B5 or Pantothenic acid (mg/100g)',
    'Vitamin B6 (mg/100g)', 'Vitamin B9 or Folate (µg/100g)', 'Vitamin B12 (µg/100g)'
]

# Check if columns are already string type, if not, convert them
for col in columns_to_convert:
    if df[col].dtype != 'object':
        df[col] = df[col].astype(str)

# Replace ",", remove "<" symbol, replace "-" by null value
for col in columns_to_convert:
    df[col] = df[col].str.replace(',', '.').str.replace('<', '').str.replace('-', '')

# Convert to float, handling empty strings ('') by setting them to NaN
for col in columns_to_convert:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
#counting nans
nan_counts = df[columns_to_convert].isna().sum()

# Order the counts in descending order
nan_counts_sorted = nan_counts.sort_values(ascending=False)

# Print the NaN counts exhaustively
for column_name, count in nan_counts_sorted.items():
    print(f"['{column_name}']: {count} NaN")
# Out:
# ['Vitamin K2 (µg/100g)']: 2484 NaN
# ['galactose (g/100g)']: 2010 NaN
# ['FA 20:4 5c,8c,11c,14c (n-6) (g/100g)']: 1427 NaN
# ['Chloride (mg/100g)']: 1420 NaN
# ['Vitamin K1 (µg/100g)']: 1379 NaN
# ['lactose (g/100g)']: 1278 NaN
# ['fructose (g/100g)']: 1155 NaN
# ['maltose (g/100g)']: 1144 NaN
# ['FA 18:1 n-9 cis (g/100g)']: 1132 NaN
# ['glucose (g/100g)']: 1118 NaN
# ['Organic acids (g/100g)']: 1108 NaN
# ['sucrose (g/100g)']: 1099 NaN
# ['FA 18:2 9c,12c (n-6) (g/100g)']: 1080 NaN
# ['FA 6:0 (g/100g)']: 1073 NaN
# ['FA 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100g)']: 1064 NaN
# ['FA 4:0 (g/100g)']: 1057 NaN
# ['FA 8:0 (g/100g)']: 1049 NaN
# ['FA 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100g)']: 1025 NaN
# ['FA 18:3 c9,c12,c15 (n-3) (g/100g)']: 1024 NaN
# ['FA 10:0 (g/100g)']: 1000 NaN
# ['Beta-carotene (µg/100g)']: 971 NaN
# ['Starch (g/100g)']: 962 NaN
# ['Selenium (µg/100g)']: 924 NaN
# ['FA 12:0 (g/100g)']: 885 NaN
# ['Iodine (µg/100g)']: 880 NaN
# ['Vitamin D (µg/100g)']: 814 NaN
# ...

# %% [markdown]
# * There's surprinsigly few Energy values; luckily this can be calculated based on total Carbs, Prot, Fats, Fiber which have less NaN.
# * VitB are better documented but probably mostly present for grains.
# * We'll keep most of the values with less than 600 NaN.
# * And keep nutritionals that are specially recognised for their importance such as vitC and B9

# %%
#let's drop micronutrients that are not of interest #keeping C, VitC
columns_to_drop_nan = ['Protein, crude, N x 6.25 (g/100g)', 'Vitamin K2 (µg/100g)', 'galactose (g/100g)', 'FA 20:4 5c,8c,11c,14c (n-6) (g/100g)', 'Chloride (mg/100g)', 'Vitamin K1 (µg/100g)', 
                       'lactose (g/100g)', 'fructose (g/100g)', 'maltose (g/100g)', 'FA 18:1 n-9 cis (g/100g)', 'glucose (g/100g)', 'Organic acids (g/100g)', 'sucrose (g/100g)', 'FA 18:2 9c,12c (n-6) (g/100g)', 'FA 6:0 (g/100g)', 
                       'FA 20:5 5c,8c,11c,14c,17c (n-3) EPA (g/100g)', 'FA 4:0 (g/100g)', 'FA 8:0 (g/100g)', 'FA 22:6 4c,7c,10c,13c,16c,19c (n-3) DHA (g/100g)', 'FA 18:3 c9,c12,c15 (n-3) (g/100g)', 
                       'FA 10:0 (g/100g)', 'Beta-carotene (µg/100g)', 'Starch (g/100g)', 'Selenium (µg/100g)', 'FA 12:0 (g/100g)', 'Iodine (µg/100g)', 'Vitamin D (µg/100g)', 'FA 14:0 (g/100g)', 
                       'Retinol (µg/100g)', 'FA 18:0 (g/100g)', 'FA 16:0 (g/100g)', 'Vitamin B12 (µg/100g)', 'Vitamin B5 or Pantothenic acid (mg/100g)', 'Vitamin E (mg/100g)', 'Cholesterol (mg/100g)', 
                       'Manganese (mg/100g)', 'Copper (mg/100g)', 'Polyols (g/100g)'
    ]
df.drop(columns=columns_to_drop_nan, inplace=True)

# %%
for column in df.columns:
    print(f": {column}, dtype: {df[column].dtype}")
# Out:
# : Code AGB, dtype: object
# : CIQUAL_code, dtype: int64
# : LCI Name, dtype: object
# : DQR, dtype: float64
# : EF_Score Farm, dtype: float64
# : EF_Score Process, dtype: float64
# : EF_Score Pack, dtype: float64
# : EF_Score Transp, dtype: float64
# : EF_Score Distrib, dtype: float64
# : EF_Score Consum, dtype: float64
# : EF_Score Total, dtype: float64
# : Carbon Farm, dtype: float64
# : Carbon Process, dtype: float64
# : Carbon Pack, dtype: float64
# : Carbon Transp, dtype: float64
# : Carbon Distrib, dtype: float64
# : Carbon Consum, dtype: float64
# : Carbon Total, dtype: float64
# : Ozone_CFC Farm, dtype: float64
# : Ozone_CFC Process, dtype: float64
# : Ozone_CFC Pack, dtype: float64
# : Ozone_CFC Transp, dtype: float64
# : Ozone_CFC Distrib, dtype: float64
# : Ozone_CFC Consum, dtype: float64
# : Ozone_CFC Total, dtype: float64
# : Ionising Farm, dtype: float64
# : Ionising Process, dtype: float64
# : Ionising Pack, dtype: float64
# : Ionising Transp, dtype: float64
# ...

# %%
# Nut Columns to kg
columns_to_kg = [
    'Energy, Regulation EU No 1169/2011 (kJ/100g)',
    'Energy, Regulation EU No 1169/2011 (kcal/100g)',
    'Energy, N x Jones\' factor, with fibres (kJ/100g)',
    'Energy, N x Jones\' factor, with fibres (kcal/100g)',
    'Water (g/100g)',
    'Protein (g/100g)',
    'Carbohydrate (g/100g)',
    'Fat (g/100g)',
    'Sugars (g/100g)',
    'Fibres (g/100g)',
    'Ash (g/100g)',
    'Alcohol (g/100g)',
    'FA saturated (g/100g)',
    'FA mono (g/100g)',
    'FA poly (g/100g)',
    'Salt (g/100g)',
    'Calcium (mg/100g)',
    'Iron (mg/100g)',
    'Magnesium (mg/100g)',
    'Phosphorus (mg/100g)',
    'Potassium (mg/100g)',
    'Sodium (mg/100g)',
    'Zinc (mg/100g)',
    'Vitamin C (mg/100g)',
    'Vitamin B1 or Thiamin (mg/100g)',
    'Vitamin B2 or Riboflavin (mg/100g)',
    'Vitamin B3 or Niacin (mg/100g)',
    'Vitamin B6 (mg/100g)',
    'Vitamin B9 or Folate (µg/100g)'
]
df[columns_to_kg] = df[columns_to_kg] / 10

# Change the column names to reflect the unit change from "/100g" to "/kg"
df.rename(columns=lambda x: x.replace('/100g', '/kg'), inplace=True)
display(df.head())
# Out:
#   Code AGB  CIQUAL_code                                           LCI Name  \
# 0    11084        11084                                 Seaweed, agar, raw
# 1    11023        11023                              Garlic, powder, dried
# 2    11000        11000                                      Garlic, fresh
# 3    11093        11093                                        Dill, fresh
# 4    20995        20995  Sea lettuce (Enteromorpha sp.), dried or dehyd...
#
#     DQR  EF_Score Farm  EF_Score Process  EF_Score Pack  EF_Score Transp  \
# 0  2.99       0.650633          0.499682       0.024315         0.046064
# 1  4.11       0.033498          0.000000       0.050344         0.015192
# 2  3.54       0.041872          0.000000       0.000000         0.013993
# 3  3.75       0.082777          0.000000       0.027078         0.012938
# 4  2.99       0.650633          0.499682       0.024315         0.046064
#
#    EF_Score Distrib  EF_Score Consum  ...  Phosphorus (mg/kg)  \
# ...

# %%
for column in df.columns:
    print(f" {column}, NaN: {df[column].isna().sum()}")
# Out:
#  Code AGB, NaN: 0
#  CIQUAL_code, NaN: 0
#  LCI Name, NaN: 0
#  DQR, NaN: 0
#  EF_Score Farm, NaN: 0
#  EF_Score Process, NaN: 0
#  EF_Score Pack, NaN: 0
#  EF_Score Transp, NaN: 0
#  EF_Score Distrib, NaN: 0
#  EF_Score Consum, NaN: 0
#  EF_Score Total, NaN: 0
#  Carbon Farm, NaN: 0
#  Carbon Process, NaN: 0
#  Carbon Pack, NaN: 0
#  Carbon Transp, NaN: 0
#  Carbon Distrib, NaN: 0
#  Carbon Consum, NaN: 0
#  Carbon Total, NaN: 0
#  Ozone_CFC Farm, NaN: 0
#  Ozone_CFC Process, NaN: 0
#  Ozone_CFC Pack, NaN: 0
#  Ozone_CFC Transp, NaN: 0
#  Ozone_CFC Distrib, NaN: 0
#  Ozone_CFC Consum, NaN: 0
#  Ozone_CFC Total, NaN: 0
#  Ionising Farm, NaN: 0
#  Ionising Process, NaN: 0
#  Ionising Pack, NaN: 0
#  Ionising Transp, NaN: 0
#  Ionising Distrib, NaN: 0
#  Ionising Consum, NaN: 0
#  Ionising Total, NaN: 0
#  NMVOC Farm, NaN: 0
#  NMVOC Process, NaN: 0
#  NMVOC Pack, NaN: 0
#  NMVOC Transp, NaN: 0
#  NMVOC Distrib, NaN: 0
#  NMVOC Consum, NaN: 0
#  NMVOC Total, NaN: 0
# ...

# %% [markdown]
# Filling in missing Energy NaN
# * I will keep only  Energy, Regulation EU No 1169/2011 (kJ/kg) columns so that I don't use fiber in the calculation.
#  (Indeed fiber has been overestimated when removing "<")
# * I will drop Energy NJones and Energy kcal (4.184  # Convert kJ to kcal)

# %%
#columns_to_drop = ['Energy, N x Jones\' factor, with fibres (kJ/kg)', 'Energy, N x Jones\' factor, with fibres (kcal/kg)','Energy, Regulation EU No 1169/2011 (kcal/kg)']
#df.drop(columns=columns_to_drop, inplace=True)

# %%
# using Atwater factors (per kilogram)
atwater_factors = {
    'Protein': 17,      # 17 kJ/g 
    'Carbohydrate': 17, # 17 kJ/g 
    'Fat': 37,          # 37 kJ/g 
    'Sugars': 17,       # 17 kJ/g 
}

# convert g/kg to kJ/kg
total_energy_kj = (
    df['Protein (g/kg)'] * atwater_factors['Protein'] +
    df['Carbohydrate (g/kg)'] * atwater_factors['Carbohydrate'] +
    df['Fat (g/kg)'] * atwater_factors['Fat'] +
    df['Sugars (g/kg)'] * atwater_factors['Sugars']
)

# Assign calculated values to missing values in 'Energy, Regulation EU No 1169/2011 (kJ/kg)'
df['Energy, Regulation EU No 1169/2011 (kJ/kg)'].fillna(total_energy_kj, inplace=True)
df.rename(columns={'Energy, Regulation EU No 1169/2011 (kJ/kg)': 'Energy (kJ/kg)'}, inplace=True)

# %% [markdown]
# # 04 - First EDA
# *  Exploratory data analysis

# %%
#Categoricals: food categories
#Numericals: all the rest.

# %%
categorical = df.select_dtypes(include=['object'])
categorical.isnull().sum()
# Out:
# Code AGB             0
# LCI Name             0
# Group_name          40
# Subgroup_name       40
# SubSubgroup_name    40
# Food_name            0
# dtype: int64

# %%
numerical = df.select_dtypes(np.number)
numerical.nunique().sort_values(ascending=False)
# Out:
# CIQUAL_code         2496
# EF_Score Total      1519
# WU Total            1459
# Ionising Total      1458
# NMVOC Total         1455
#                     ...
# SubSubgroup_code      83
# Subgroup_code         63
# Alcohol (g/kg)        52
# Group_code            11
# Unnamed: 132           0
# Length: 157, dtype: int64

# %% [markdown]
# ## First exploration

# %%
columns_to_plot = ["Carbon Total","EF_Score Total","LU Total","WU Total","Energy Total"]

# %%
from scipy.stats import norm, expon
# Set up the subplots
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(16, 8))
fig.suptitle('Distribution Plots before Transformation', y=1.02)

# Data is continuous so I can make violinplots for each column
for col, ax in zip(columns_to_plot, axes[1]):
    sns.violinplot(data=df, x=col, ax=ax, orient='v', color='lightcoral', width=0.3)
    ax.set_title(f'Violin plot of {col}')
    ax.set_xlabel('')
    ax.set_ylabel('')
    
# Create distribution plots for each column
for col, ax in zip(columns_to_plot, axes.flatten()):
    sns.histplot(df[col], kde=True, ax=ax, stat='density')  # Use stat='density' for probability density estimation
    
    # Add theoretical normal curve
    x = np.linspace(df[col].min(), df[col].max(), 1000)
    normal_curve = norm.pdf(x, loc=df[col].mean(), scale=df[col].std())
    ax.plot(x, normal_curve, color='red', label='Theoretical Normal Curve')
    
    # Add theoretical exponential curve
    exponential_curve = expon.pdf(x, scale=df[col].mean())  # Exponential distribution with mean as scale parameter
    ax.plot(x, exponential_curve, color='green', label='Theoretical Exponential Curve')
    
    ax.set_title(f'Distribution of ({col})')
    ax.legend()

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# /Users/Anne-so1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1599: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /Users/Anne-so1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1599: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /Users/Anne-so1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1599: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /Users/Anne-so1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1599: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /Users/Anne-so1/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1599: UserWarning: Vertical orientation ignored with only `x` specified.
# ...

# %% [markdown]
# ## First analysis

# %%
#x/y split
X = df[["Carbohydrate (g/kg)", 
"Fat (g/kg)",  
"Protein (g/kg)"
]]
y = df['Carbon Total']

# %%
#Checking Independance of X
correlations_matrix = X.corr() #Pearson coeff for linear relationship
sns.heatmap(correlations_matrix, annot=True)
plt.show()
#ok

# %%
xy = pd.concat([X, y], axis=1)

# Compute the correlation matrix using Pearson correlation coefficient
xycorrelation_matrix = xy.corr()

# Plot the correlation matrix as a heatmap
sns.heatmap(xycorrelation_matrix, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title('Correlation Matrix of X and y')
plt.show()

# %% [markdown]
# ## 05 - Exhaustive Correlation Analysis
# * selecting highest correlations
# * to reduce the number of numerical variables

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

correlation_matrix = numerical.corr(method='pearson')
filtered_correlation = correlation_matrix[((correlation_matrix > 0.2) | (correlation_matrix < -0.2))&(correlation_matrix < 1) ]

# Stack the filtered values into a DataFrame
filtered_correlation_stacked = filtered_correlation.stack()

# Create a DataFrame from the stacked values
summary_table = pd.DataFrame(filtered_correlation_stacked, columns=['Correlation'])

# Print the summary table
print("Summary Table of Correlations Above 0.2 or Below -0.2:")
display(summary_table)
# Reset display options to default
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
# Summary Table of Correlations Above 0.2 or Below -0.2:
#                                                                                            Correlation
# CIQUAL_code                                  SubSubgroup_code                                -0.305479
#                                              Energy, Regulation EU No 1169/2011 (kcal/kg)    -0.273774
#                                              Water (g/kg)                                     0.203348
# DQR                                          EF_Score Transp                                  0.231604
#                                              NMVOC Farm                                       0.262116
#                                              NMVOC Transp                                     0.247036
#                                              NMVOC Total                                      0.264682
# ...

# %% [markdown]
# ### Comments:
# #### ENVIRONMENT (env)
# - EF Score is dependant of all the other (env) environmental indicators.
# - EF_Score is very correlated to Carbon, therefore the (nut)/(env) associations are similar
# - Farming stage and Total are very correlated
# - What happens through stage? let's have a closer look at EF_Score:
#     - EF_Score Farm +(Protein, Zinc,B3)
#     - EF_Score Process+(Mg,K,B3)
#     - EF_Score Pack: not related to (nut)
#     - EF_Score Distrib	+(Protein, -Carb, -Sugars, Zinc) : and also a larger number of (env).
#     - EF_Score Consum +(Protein, Zinc, B3, -Sugars)
#     - EF_Score Total +(Protein, Zinc, B3)
#
# #### NUTRITIONAL (nut)
# - Vitamins B are all dependant of each other. B3 would be a good one to keep.
#
# #### DQR
# - The Higher the DQR, the worse is data quality.
# - DQR is highest with; EF transp, NMVOC, Particulates, Sweet waterAcid and Eutroph, Water Use. therefore those will be deprioritized for this analysis
#
# #### Food groups
# - Food Group and Subgroup have associations with Sweet Water impact, Earth Eutroph
#
#
# #### intermediate conclusion
# - surprisingly,(nut) Energy, Fat and Saturated Fat are hardly associated with (env)
# - Protein, B3 and Zinc show the most frequent positive association
# - Carbs and Sugars show the most frequent negative association
# - Later on we should check if the association is due to animal/vegetable nature of source foods
#
# #### MOVING FORWARD
# - Let's remove nutritionals with no interaction as per table below
# - let's keep only 1 stage per indicator (env) (farming or total of stages)

# %% [markdown]
# | Very Low env+nut interaction  | Low interaction (2 to 3) | High interaction (>3)|
# | ------------------------ | ----------------| -----------------|
# | 1. Energy                | 1. Fat          | 1. FA poly       |
# | 2. Sodium                | 2. Water        | 2. Sugars        |
# | 3. Vitamin C             | 3. Fibres       | 3. Carbohydrate  |
# | 4. Sodium                | 4. Ash          | 4. Protein       |
# | 5. Calcium               | 5. FA poly      | 5. Sugars        |
# | 6. Salt                  | 6. Iron         | 6. Magnesium     |
# | 7. FA mono               | 7. Phosphorus   | 7. Potassium     |
# | 8. FA saturated          | 8. Vitamin B1 or Thiamin | 8. Zinc  |
# | 9. Calcium               | 9. Vitamin B2 or Riboflavin | 9. Vitamin B3 or Niacin |

# %% [markdown]
# ## 06 - Trimming after analysis

# %%
## let's now drop the columns with less correlations
columns_to_drop = [
    'Energy (kJ/kg)',
    'Energy, Regulation EU No 1169/2011 (kcal/kg)',
    'Sodium (mg/kg)',
    'Vitamin C (mg/kg)',
    'Sodium (mg/kg)',
    'Calcium (mg/kg)',
    'Salt (g/kg)',
    'FA mono (g/kg)',
    'FA saturated (g/kg)',
    'Calcium (mg/kg)',
    'Code AGB', 'LCI Name', 'DQR \nOverall',	'P','TiR',	'GR',	'TeR', 
'Food_name' 
]

df.drop(columns=columns_to_drop, inplace=True)
df.isnull().sum()

# %%
# look on null values
pd.set_option('display.max_rows', None)
null_counts_descending = df.isnull().sum().sort_values(ascending=False)

# in descending order
print("Null Value Counts (Descending Order):")
print(null_counts_descending)

# Reset display option to default
pd.reset_option('display.max_rows')
# Out:
# Null Value Counts (Descending Order):
# Unnamed: 132                        2510
# Vitamin B9 or Folate (µg/kg)         634
# Vitamin B2 or Riboflavin (mg/kg)     593
# Vitamin B1 or Thiamin (mg/kg)        578
# Vitamin B3 or Niacin (mg/kg)         573
# Vitamin B6 (mg/kg)                   563
# Zinc (mg/kg)                         533
# Phosphorus (mg/kg)                   530
# Magnesium (mg/kg)                    506
# Potassium (mg/kg)                    499
# Iron (mg/kg)                         474
# FA poly (g/kg)                       459
# Carbohydrate (g/kg)                  305
# Sugars (g/kg)                        289
# Water (g/kg)                         269
# Ash (g/kg)                            72
# Fibres (g/kg)                         55
# SubSubgroup_name                      40
# Subgroup_name                         40
# Group_name                            40
# Fat (g/kg)                             8
# Alcohol (g/kg)                         6
# ...

# %%
df.shape
# Out:
# (2510, 147)

# %%
#remove unnamed column (index 121)
for idx, col in enumerate(df.columns):
    print(f"Column Index: {idx}, Column Name: {col}")
# Out:
# Column Index: 0, Column Name: CIQUAL_code
# Column Index: 1, Column Name: DQR
# Column Index: 2, Column Name: EF_Score Farm
# Column Index: 3, Column Name: EF_Score Process
# Column Index: 4, Column Name: EF_Score Pack
# Column Index: 5, Column Name: EF_Score Transp
# Column Index: 6, Column Name: EF_Score Distrib
# Column Index: 7, Column Name: EF_Score Consum
# Column Index: 8, Column Name: EF_Score Total
# Column Index: 9, Column Name: Carbon Farm
# Column Index: 10, Column Name: Carbon Process
# Column Index: 11, Column Name: Carbon Pack
# Column Index: 12, Column Name: Carbon Transp
# Column Index: 13, Column Name: Carbon Distrib
# Column Index: 14, Column Name: Carbon Consum
# Column Index: 15, Column Name: Carbon Total
# Column Index: 16, Column Name: Ozone_CFC Farm
# Column Index: 17, Column Name: Ozone_CFC Process
# Column Index: 18, Column Name: Ozone_CFC Pack
# Column Index: 19, Column Name: Ozone_CFC Transp
# Column Index: 20, Column Name: Ozone_CFC Distrib
# ...

# %%
df = df.drop(df.columns[121], axis=1)
for idx, col in enumerate(df.columns):
    print(f"Column Index: {idx}, Column Name: {col}")
# Out:
# Column Index: 0, Column Name: CIQUAL_code
# Column Index: 1, Column Name: DQR
# Column Index: 2, Column Name: EF_Score Farm
# Column Index: 3, Column Name: EF_Score Process
# Column Index: 4, Column Name: EF_Score Pack
# Column Index: 5, Column Name: EF_Score Transp
# Column Index: 6, Column Name: EF_Score Distrib
# Column Index: 7, Column Name: EF_Score Consum
# Column Index: 8, Column Name: EF_Score Total
# Column Index: 9, Column Name: Carbon Farm
# Column Index: 10, Column Name: Carbon Process
# Column Index: 11, Column Name: Carbon Pack
# Column Index: 12, Column Name: Carbon Transp
# Column Index: 13, Column Name: Carbon Distrib
# Column Index: 14, Column Name: Carbon Consum
# Column Index: 15, Column Name: Carbon Total
# Column Index: 16, Column Name: Ozone_CFC Farm
# Column Index: 17, Column Name: Ozone_CFC Process
# Column Index: 18, Column Name: Ozone_CFC Pack
# Column Index: 19, Column Name: Ozone_CFC Transp
# Column Index: 20, Column Name: Ozone_CFC Distrib
# ...

# %% [markdown]
# ### Saving file

# %%
####saving intermediate file
#df.to_csv('ciqual_agribalyse_reduced.csv', index=False)

# %%
#import pymysql                        # for getting data from a SQL database
#from sqlalchemy import create_engine  # for establishing the connection and authentication
#from getpass import getpass  # To get the password without showing the input

# %%
#password = getpass()
# Out:
#  ········

# %%
#connection_string = 'mysql+pymysql://root:'+password+'@localhost/CIQUALAGRIBALYSE'
#engine = create_engine(connection_string)

# %%
#df.to_sql('ciqual_agribalyse', engine, if_exists='replace', index=False)

# %% [markdown]
# # 07 - Predictive models
# * new dataframe 'data'
# * smaller number of variables
# * Outliers: won't be considered
# * Encoding Categorical Data : already encoded

# %% [raw]
# #we will keep only a small number of targets
# 'EF_Score Farm','EF_Score Total','Carbon Total','LU Total'
# #and of categories
# "FA poly (g/kg)",
# "Sugars (g/kg)",
# "Carbohydrate (g/kg)",
# "Protein (g/kg)",
# "Sugars (g/kg)",
# "Magnesium (mg/kg)",
# "Potassium (mg/kg)",
# "Zinc (mg/kg)",
# "Vitamin B3 or Niacin (mg/kg)"
# #and groups
# "Group_code", "Group_name"

# %%
data = df[['EF_Score Farm', 'EF_Score Total', 'Carbon Total', 'LU Total', 'Group_code', 'Group_name',
                    'FA poly (g/kg)', 'Sugars (g/kg)', 'Carbohydrate (g/kg)', 'Protein (g/kg)', 'Sugars (g/kg)',
                    'Magnesium (mg/kg)', 'Potassium (mg/kg)', 'Zinc (mg/kg)', 'Vitamin B3 or Niacin (mg/kg)']].copy()

print(data.shape)
# Out:
# (2510, 15)

# %%
data.isnull().sum()
# Out:
# EF_Score Farm                     0
# EF_Score Total                    0
# Carbon Total                      0
# LU Total                          0
# Group_code                        0
# Group_name                       40
# FA poly (g/kg)                  459
# Sugars (g/kg)                   289
# Carbohydrate (g/kg)             305
# Protein (g/kg)                    5
# Sugars (g/kg)                   289
# Magnesium (mg/kg)               506
# Potassium (mg/kg)               499
# Zinc (mg/kg)                    533
# Vitamin B3 or Niacin (mg/kg)    573
# dtype: int64

# %%
data.dropna(inplace=True) #losing half the values
data.shape
# Out:
# (1389, 15)

# %% [markdown]
# Checking collinearity

# %%
X = data[['FA poly (g/kg)', 'Sugars (g/kg)', 'Carbohydrate (g/kg)', 
          'Protein (g/kg)', 'Magnesium (mg/kg)', 
          'Potassium (mg/kg)', 'Zinc (mg/kg)', 'Vitamin B3 or Niacin (mg/kg)']]
y = data['EF_Score Total']
correlations_matrix = X.corr()
sns.heatmap(correlations_matrix, annot=True, fmt=".2f", linewidths=.5)
plt.show()
#carbs and sugars,
#protein and zinc, 
#protein and b3
#magnesium and potassium
#magnesium and zinc
    #I will then keep: fa poly, carbs, protein, magnesium

# %% [markdown]
# # a) model nut/env

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Define features (X) and target variable (y)
X = data[['Carbohydrate (g/kg)', 
          'Protein (g/kg)', 'Magnesium (mg/kg)', 
          'Potassium (mg/kg)']]
y = data['EF_Score Total']

# Scale the features using Min-Max scaling
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=40)

# Initialize the Linear Regression model
model = LinearRegression()

# Train the model on the training data
model.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = model.predict(X_test)

# %% [markdown]
# #### Model Validation

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error (MSE):', mse) #accuracy
print('R-squared (R2):', r2) #proportion of the variance in the dependent variable is explained by the model

# Optional: Model Interpretation
coefficients = model.coef_
print('Coefficients:', coefficients)
# Out:
# Mean Squared Error (MSE): 0.2815109351767934
# R-squared (R2): 0.17786582645338045
# Coefficients: [-0.37491493  4.46604895 -1.75469365  1.65618534]

# %% [markdown]
# ## b) model food groups / env

# %%
X1 = data[['Group_code']]  #  'Group_code' is already numeric
y1 = data['EF_Score Total']

# Split the data into training and testing sets (80% train, 20% test)
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=40)

# Initialize the Linear Regression model
model1 = LinearRegression()

# Fit the model on the training data
model1.fit(X_train1, y_train1)

# Make predictions on the testing data
y_pred1 = model1.predict(X_test1)

# %% [markdown]
# #### Model Validation

# %%
#from sklearn.metrics import mean_squared_error, r2_score
mse1 = mean_squared_error(y_test1, y_pred1)
r2_1 = r2_score(y_test1, y_pred1)

print('Mean Squared Error (MSE):', mse1) #accuracy
print('R-squared (R2):', r2_1) #proportion of the variance in the dependent variable is explained by the model

# Optional: Model Interpretation
coefficients = model1.coef_
print('Coefficients:', coefficients)
# Out:
# Mean Squared Error (MSE): 0.3493355073151542
# R-squared (R2): -0.02021137621764768
# Coefficients: [-0.01645553]

# %% [markdown]
# This model is worse than blind guess.
# Interpretation would be tricky because the categorical labelling is not ordinal. Let's Plot instead

# %% [markdown]
# # 08 - EDA 2

# %%
#Aggregated (env) Score per food Group
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.boxplot(x='Group_name', y='EF_Score Total', data=data)
plt.title('Boxplot of EF_Score Total by Group_name')
plt.xlabel('Group_name')
plt.ylabel('EF_Score Total')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
# (env) Carbon Score per food Group
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.boxplot(x='Group_name', y='Carbon Total', data=data)
plt.title('Boxplot of Climate Change Impact by Group_name')
plt.xlabel('Group_name')
plt.ylabel('Carbon Total')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
#In Tableau we visualize better the positive and negative relationships between (nut) and (env)
# scatter plot for 'Carbohydrate (g/kg)'
plt.figure(figsize=(8, 6))
plt.scatter(data['Carbohydrate (g/kg)'], data['EF_Score Total'], alpha=0.5)
plt.title('EF_Score Total vs Carbohydrate (g/kg)')
plt.xlabel('Carbohydrate (g/kg)')
plt.ylabel('EF_Score Total')
plt.grid(True)
plt.show()

#scatter plot for 'Protein (g/kg)'
plt.figure(figsize=(8, 6))
plt.scatter(data['Protein (g/kg)'], data['EF_Score Total'], alpha=0.5)
plt.title('EF_Score Total vs Protein (g/kg)')
plt.xlabel('Protein (g/kg)')
plt.ylabel('EF_Score Total')
plt.grid(True)
plt.show()

#scatter plot for 'Magnesium (mg/kg)'
plt.figure(figsize=(8, 6))
plt.scatter(data['Magnesium (mg/kg)'], data['EF_Score Total'], alpha=0.5)
plt.title('EF_Score Total vs Magnesium (mg/kg)')
plt.xlabel('Magnesium (mg/kg)')
plt.ylabel('EF_Score Total')
plt.grid(True)
plt.show()

# scatter plot for 'Potassium (mg/kg)'
plt.figure(figsize=(8, 6))
plt.scatter(data['Potassium (mg/kg)'], data['EF_Score Total'], alpha=0.5)
plt.title('EF_Score Total vs Potassium (mg/kg)')
plt.xlabel('Potassium (mg/kg)')
plt.ylabel('EF_Score Total')
plt.grid(True)
plt.show()

# %% [markdown]
# # 09 - Radar

# %%
from sklearn.preprocessing import MinMaxScaler

# Define the nutritional columns
nutrition_columns = ['FA poly (g/kg)', 'Sugars (g/kg)', 'Carbohydrate (g/kg)', 
                     'Protein (g/kg)', 'Magnesium (mg/kg)', 'Potassium (mg/kg)', 
                     'Zinc (mg/kg)', 'Vitamin B3 or Niacin (mg/kg)']

# Calculate the number of nutritional columns
num_vars = len(nutrition_columns)

# Create subplots
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Define colors for each Group_name
colors = plt.cm.tab10(np.linspace(0, 1, 10))

# Iterate over Group_names and create radar plot
for group_name, color in zip(df['Group_name'].unique(), colors):
    # Filter the DataFrame by Group_name
    group_data = df[df['Group_name'] == group_name]

    # Calculate mean values for nutritional columns
    group_mean = group_data[nutrition_columns].mean()

    # Skip groups with NaN values in nutrition columns
    if group_mean.isnull().any():
        continue

    # Normalize nutritional values to the range [0, 1]
    scaler = MinMaxScaler()
    group_normalized = scaler.fit_transform(group_mean.values.reshape(-1, 1)).flatten()

    # Compute angle for each axis
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    group_normalized = np.concatenate((group_normalized, [group_normalized[0]]))
    angles += angles[:1]

    # Plot
    ax.fill(angles, group_normalized, color=color, alpha=0.5)
    ax.plot(angles, group_normalized, color=color, linewidth=2, linestyle='solid', label=group_name)

# Add nutritional labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(nutrition_columns)

# Add legend
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1))

# Show the plot
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Define the nutritional columns
nutrition_columns = ['FA poly (g/kg)', 'Sugars (g/kg)', 'Carbohydrate (g/kg)', 
                     'Protein (g/kg)', 'Magnesium (mg/kg)', 'Potassium (mg/kg)', 
                     'Zinc (mg/kg)', 'Vitamin B3 or Niacin (mg/kg)']

# Group the DataFrame by 'Group_name'
grouped_df = df.groupby('Group_name')

# Calculate the number of groups and radar plots to be plotted
num_groups = len(grouped_df)
num_plots = num_groups if num_groups <= 12 else 12

# Arrange the plots in three lines of four
num_rows = min(3, (num_plots + 3) // 4)
num_cols = min(4, num_plots)

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 12))

# Iterate over groups and create radar plots
for ax, (group_name, group_data) in zip(axes.flatten(), grouped_df):
    # Calculate mean values for nutritional columns
    group_mean = group_data[nutrition_columns].mean()

    # Skip groups with NaN values in nutrition columns
    if group_mean.isnull().any():
        continue

    # Normalize nutritional values to the range [0, 1]
    scaler = MinMaxScaler()
    group_normalized = scaler.fit_transform(group_mean.values.reshape(-1, 1)).flatten()

    # Define the number of variables
    num_vars = len(nutrition_columns)

    # Compute angle for each axis
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

    # The plot is a circle, so we need to "complete the loop" and append the start
    group_normalized = np.concatenate((group_normalized,[group_normalized[0]]))
    angles += angles[:1]

    # Plot
    ax.fill(angles, group_normalized, color='skyblue', alpha=0.5)
    ax.plot(angles, group_normalized, color='blue', linewidth=2, linestyle='solid')
    ax.set_yticklabels([])
    ax.set_title(f"Nutritionals Radar Plot for {group_name}")

    # Add labels
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(nutrition_columns, rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Define the nutritional columns
nutrition_columns = ['FA poly (g/kg)', 'Sugars (g/kg)', 'Carbohydrate (g/kg)', 
                     'Protein (g/kg)', 'Magnesium (mg/kg)', 'Potassium (mg/kg)', 
                     'Zinc (mg/kg)', 'Vitamin B3 or Niacin (mg/kg)']

# Calculate the number of nutritional columns
num_vars = len(nutrition_columns)

# Create subplots
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Define colors for each Group_name
colors = plt.cm.tab10(np.linspace(0, 1, 10))

# Iterate over Group_names and create radar plot
for group_name, color in zip(df['Group_name'].unique(), colors):
    # Filter the DataFrame by Group_name
    group_data = df[df['Group_name'] == group_name]

    # Calculate mean values for nutritional columns
    group_mean = group_data[nutrition_columns].mean()

    # Skip groups with NaN values in nutrition columns
    if group_mean.isnull().any():
        continue

    # Compute angle for each axis
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    group_mean = np.concatenate((group_mean.values, [group_mean.values[0]]))
    angles += angles[:1]

    # Plot
    ax.fill(angles, group_mean, color=color, alpha=0.5)
    ax.plot(angles, group_mean, color=color, linewidth=2, linestyle='solid', label=group_name)

# Add nutritional labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(nutrition_columns)

# Add legend
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1))

# Show the plot
plt.show()
